# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
mayor_precio_fila = ds.loc[ds['price'].idxmax()]
mayor_precio = mayor_precio_fila["price"]
direccion = mayor_precio_fila["address"]
print(f"la casa con direccion en {direccion}, es la mas cara con un precio de {mayor_precio} eur")
# Out:
# la casa con direccion en El Escorial, es la mas cara con un precio de 8500000 eur

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
menor_precio_fila = ds.loc[ds['price'].idxmin()]
menor_precio = menor_precio_fila['price']
direcion = menor_precio_fila['address']
print(f"la casa con direccion en {direcion}, es la mas barata con un precio de {menor_precio} eur")
# Out:
# la casa con direccion en Parla, es la mas barata con un precio de 0 eur

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
fila_mayor_superficie = ds.loc[ds['surface'].idxmax()]
fila_menor_superficie = ds.loc[ds['surface'].idxmin()]
mayor_superficie = fila_mayor_superficie['surface']
menor_superficie = fila_menor_superficie['surface']
direccion_menor_superficie = fila_menor_superficie['address']
direccion_mayor_superficie = fila_mayor_superficie ['address']

print(f"la casa mas grande esta ubicada en {direccion_mayor_superficie} y su superficie es de {mayor_superficie} metros")
print(f"la cas mas pequeña esta ubicada en {direccion_menor_superficie} y su seperficie es de {menor_superficie} metros")
# Out:
# la casa mas grande esta ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# la cas mas pequeña esta ubicada en Calle Amparo,  Madrid Capital y su seperficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
poblaciones =  ds['level5'].unique()
poblaciones_separadas_por_comas = ', '.join(poblaciones)

print(f"hay {len(poblaciones)} diferentes: {poblaciones_separadas_por_comas}")
# Out:
# hay 168 diferentes: Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

hay_na = ds.isna().any().any()
if hay_na:
    columnas_con_na = ds.isna().any()
    print("Columnas con NAs:")
    print(columnas_con_na[columnas_con_na == True])

    filas_con_na = ds.isna().any(axis=1)
    print("\nFilas con NAs:")
    print(filas_con_na[filas_con_na == True])
# Out:
# Columnas con NAs:
# realEstate_name     True
# phone_realEstate    True
# rooms               True
# bathrooms           True
# surface             True
# description         True
# level4              True
# level6              True
# level7              True
# level8              True
# zipCode             True
# customZone          True
# dtype: bool
#
# Filas con NAs:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15330    True
# 15331    True
# 15332    True
# 15333    True
# 15334    True
# Length: 15335, dtype: bool

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
dimensiones_originales = ds.shape
# Eliminar filas con valores Na
ds_sin_na = ds.dropna()
# Dimensiones después de eliminar los NaN
dimensiones_sin_na = ds_sin_na.shape
print(f"Dimensiones originales: {dimensiones_originales}")
print(f"Dimensiones después de eliminar NA: {dimensiones_sin_na}")
# Out:
# Dimensiones originales: (15335, 37)
# Dimensiones después de eliminar NA: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
arroyomolinos_df = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

# Calcular la media de los precios en esa población
media_precio = arroyomolinos_df['price'].mean()

# Imprimir el resultado
print(f"La media de los precios en Arroyomolinos es: {media_precio} eur")
# Out:
# La media de los precios en Arroyomolinos es: 294541.59854014596 eur

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

# Trazar el histograma de los precios
plt.figure(figsize=(8, 6))
plt.hist(arroyomolinos_df['price'], bins=10, color='blue', alpha=0.7, edgecolor='black')
plt.title('Histograma de Precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio')
plt.ylabel('Número de casas')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# El histograma muestra la distribución de precios de propiedades en Arroyomolinos (Madrid). Se puede observar que la mayoría de los precios se concentran en un rango específico entre los 200000 y 400000, indicando que las propiedades tienen un precio promedio. También se puede notar si hay algún valor atípico, en este caso la parte laterales del rango de precios son los que muestran los valores atipicos.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
valdemorillo_df = ds[ds['level5'] == 'Valdemorillo']
galapagar_df = ds[ds['level5'] == 'Galapagar']
media_precio_valdemorillo = valdemorillo_df['price'].mean()
media_precio_galapagar = galapagar_df['price'].mean()
print(f"media de precio Galapagar {media_precio_galapagar},media de precio Valdemorillo {media_precio_valdemorillo}")
# Out:
# media de precio Galapagar 360063.20238095237,media de precio Valdemorillo 363860.2931034483

# %% [markdown]
# Los precios promedios son muy similares solo hay una diferencia de casi 3800 entre los dos

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
ds['pps'] = ds['price'] / ds['surface']
#declarar siempre despues de nuevo campo
valdemorillo_df = ds[ds['level5'] == 'Valdemorillo']
galapagar_df = ds[ds['level5'] == 'Galapagar']
# Calcular el promedio del precio por metro cuadrado para ambas poblaciones
promedio_valdemorillo = valdemorillo_df['pps'].mean()
promedio_galapagar = galapagar_df['pps'].mean()

print(f"Promedio de precio por metro cuadrado en Valdemorillo: {promedio_valdemorillo:.2f} €/m²")
print(f"Promedio de precio por metro cuadrado en Galapagar: {promedio_galapagar:.2f} €/m²")

# Conclusión
if promedio_valdemorillo == promedio_galapagar:
    print("Los promedios de precio por metro cuadrado en Valdemorillo y Galapagar son iguales.")
else:
    print("Los promedios de precio por metro cuadrado en Valdemorillo y Galapagar son diferentes.")
# Out:
# Promedio de precio por metro cuadrado en Valdemorillo: 1317.95 €/m²
# Promedio de precio por metro cuadrado en Galapagar: 1606.32 €/m²
# Los promedios de precio por metro cuadrado en Valdemorillo y Galapagar son diferentes.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
ds = ds.dropna(subset=['price', 'surface'])
plt.figure(figsize=(6,4))
plt.scatter(ds['surface'], ds['price'], color='blue', alpha=0.5)

# Añadir etiquetas y título
plt.title("Relación entre la superficie y el precio de las casas")
plt.xlabel("Superficie (m²)")
plt.ylabel("Precio (€)")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# no hay una relacion directa entre la superficie y el precio de las casas ya que tambien depende de la zona en que se encuentra la vivienda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
numero_agencias = ds['realEstate_name'].nunique()
numero_agencias
# Out:
# 1711

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
poblacion_casas = ds['level5'].value_counts()

# Encontrar la población con la mayor cantidad de casas
poblacion_mayor = poblacion_casas.idxmax()
num_casas = poblacion_casas.max()

# Imprimir la población con mayor cantidad de casas y el número de casas
print(f"La población con mayor cantidad de casas es: {poblacion_mayor} con {num_casas} casas.")
# Out:
# La población con mayor cantidad de casas es:  Madrid Capital con 6237 casas.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
cinturon_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Filtrar el DataFrame original para que solo contenga esas poblaciones en la columna 'level5'
df_cinturon_sur = ds[ds['level5'].isin(cinturon_sur)]
df_cinturon_sur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# 161           162       153440116  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# 161                                    prolucisa       916350416.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# Calcular la mediana de precios por población (columna 'level5')
mediana_precios = df_cinturon_sur.groupby('level5')['price'].median()

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
mediana_precios.plot(kind='bar', color='skyblue')

# Título y etiquetas
plt.title('Mediana de Precios por Población', fontsize=14)
plt.xlabel('Población', fontsize=12)
plt.ylabel('Mediana de Precio', fontsize=12)
plt.xticks(rotation=45, ha='right')


# Mostrar el gráfico

plt.show()

# %% [markdown]
# Podemos ver en el grafico que Getafe es el que tiene la media de precio mas elevada del cinturon sur y Fuenlabrada el de media menor del cinturon sur.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# Seleccionar las columnas relevantes del subconjunto df_cinturon_sur
columnas_interes = ['price', 'rooms', 'surface', 'bathrooms']

# Calcular la media para cada columna
media = df_cinturon_sur[columnas_interes].mean()

# Calcular la varianza muestral para cada columna
varianza = df_cinturon_sur[columnas_interes].var()

# Imprimir resultados
print("Media de cada variable:")
print(media)

print("\nVarianza muestral de cada variable:")
print(varianza)
# Out:
# Media de cada variable:
# price        222009.115629
# rooms             3.006386
# surface         111.752224
# bathrooms         1.636364
# dtype: float64
#
# Varianza muestral de cada variable:
# price        1.516638e+10
# rooms        7.045628e-01
# surface      4.263052e+03
# bathrooms    5.727273e-01
# dtype: float64

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# Agrupar por población (level5) y encontrar el índice de la casa con el precio más alto en cada grupo
idx_mayor_precio = df_cinturon_sur.groupby('level5')['price'].idxmax()

# Crear un DataFrame con las casas más caras de cada población
casas_mas_caras = df_cinturon_sur.loc[idx_mayor_precio, ['level5', 'address', 'price']]

# Imprimir el resultado
print(casas_mas_caras)
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
poblaciones_dentro_cint_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
df_subset = df_cinturon_sur[df_cinturon_sur['level5'].isin(poblaciones_dentro_cint_sur)]

# Normalizar los precios para cada población
df_subset['normalized_price'] = df_subset.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# Graficar los histogramas en el mismo gráfico
plt.figure(figsize=(10, 6))

for population in poblaciones_dentro_cint_sur:
    # Extraer los precios normalizados para cada población
    population_prices = df_subset[df_subset['level5'] == population]['normalized_price']
    
    # Graficar el histograma para esa población
    plt.hist(population_prices, bins=20, alpha=0.6, label=population)

# Añadir etiquetas y título
plt.title('Histogramas de Precios Normalizados por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend()

# Mostrar gráfico
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
df_cinturon_sur['pps'] = df_cinturon_sur['price'] / df_cinturon_sur['surface']
#declarar siempre despues de nuevo campo
Getafe_df = df_cinturon_sur[df_cinturon_sur['level5'] == 'Getafe']
Alcorcon_df = df_cinturon_sur[df_cinturon_sur['level5'] == 'Alcorcón']
# Calcular el promedio del precio por metro cuadrado para ambas poblaciones
promedio_Getafe = Getafe_df['pps'].mean()
promedio_Alcorcon = Alcorcon_df['pps'].mean()

print(f"Promedio de precio por metro cuadrado en Getafe: {promedio_Getafe:.2f} €/m²")
print(f"Promedio de precio por metro cuadrado en Alcorcón: {promedio_Alcorcon:.2f} €/m²")
# Out:
# Promedio de precio por metro cuadrado en Getafe: 2066.31 €/m²
# Promedio de precio por metro cuadrado en Alcorcón: 2239.30 €/m²
# /tmp/ipykernel_559/3908579464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cinturon_sur['pps'] = df_cinturon_sur['price'] / df_cinturon_sur['surface']

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# Obtener las 4 primeras poblaciones únicas del DataFrame df_cinturon_sur
poblaciones = df_cinturon_sur['level5'].unique()[:4]  # Solo seleccionamos las primeras 4

# Crear subplots (2 filas, 2 columnas para los 4 gráficos)
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Aplanar el array de axs para facilitar la iteración
axs = axs.flatten()

# Iterar sobre cada población y su respectivo subplot
for i, poblacion in enumerate(poblaciones):
    # Filtrar los datos del DataFrame df_cinturon_sur para la población actual
    df_pob = df_cinturon_sur[df_cinturon_sur['level5'] == poblacion]
    
    # Crear un diagrama de dispersión en la subtrama correspondiente
    axs [i].scatter(df_pob['latitude'], df_pob['longitude'], label=poblacion)
    
    # Añadir título y etiquetas a cada subplot
    axs[i].set_title(f'Población {poblacion}') 
    axs[i].set_xlabel('X')
    axs[i].set_ylabel('Y') 

# Ajustar los espacios entre los subplots para que no se solapen 
plt.tight_layout() 

# Mostrar el gráfico 
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitude y -2.2 grados longitud)
# Latitud, longitud
map = Map(basemap=basemaps.OpenStreetMap.Mapnik, center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20) 

    
# Crear el mapa centrado en Madrid
mapa = Map(center=(40.4, -3.7), zoom=12, layout=Layout(width="100%", height="600px"))

# Filtrar las 4 poblaciones (Fuenlabrada, Alcorcón, Getafe, Leganés)
fuenlabrada = df_cinturon_sur[df_cinturon_sur['level5'] == "Fuenlabrada"]
alcorcon = df_cinturon_sur[df_cinturon_sur['level5'] == "Alcorcón"]
getafe = df_cinturon_sur[df_cinturon_sur['level5'] == "getafe"]
leganes = df_cinturon_sur[df_cinturon_sur['level5']== "leganes"]

def add_markers(dataframe, mapa, color):
    for _, row in dataframe.iterrows():
        # Crear un marcador por cada coordenada de la población
        marker = Marker(location=(row['latitude'], row['longitude']), draggable=False)
        # Añadir el marcador al mapa
        mapa.add_layer(marker)

# Añadir los marcadores para cada población
add_markers(fuenlabrada, mapa, "blue")
add_markers(alcorcon, mapa, "green")
add_markers(getafe, mapa, "red")
add_markers(leganes, mapa, "purple")
mapa
# Out:
# Map(center=[40.4, -3.7], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
